# %%
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# first: cv2.waitKey(1): -1
# 1/1 [==============================] - 0s 326ms/step
# [[8.7692286e-04 5.6472957e-01 4.3439198e-01 1.5277112e-06]]
# second: cv2.waitKey(1): -1
# first: cv2.waitKey(1): -1
# 1/1 [==============================] - 0s 15ms/step
# [[1.2294141e-03 7.0632118e-01 2.9244456e-01 4.8417060e-06]]
# second: cv2.waitKey(1): -1
# first: cv2.waitKey(1): -1
# 1/1 [==============================] - 0s 13ms/step
# [[1.0958250e-03 6.8847376e-01 3.1042519e-01 5.1965717e-06]]
# second: cv2.waitKey(1): -1
# first: cv2.waitKey(1): -1
# 1/1 [==============================] - 0s 17ms/step
# [[1.2035016e-03 7.0034498e-01 2.9844624e-01 5.3501758e-06]]
# second: cv2.waitKey(1): -1
# first: cv2.waitKey(1): -1
# 1/1 [==============================] - 0s 13ms/step
# [[1.2171242e-03 6.7778546e-01 3.2099178e-01 5.5352552e-06]]
# second: cv2.waitKey(1): -1
# ...
